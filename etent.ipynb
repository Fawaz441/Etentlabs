# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r'C:\Users\Fawaz\Desktop\ML\etentlabs\main\formspring_data.csv',sep='\t')

# %%
selector1 = df['ans1'] == df['ans2']
selector2 = df['ans2'] == df['ans3']
selector3 = df['ans3'] == df['ans1']

# %%
df = df[selector1 & selector2 & selector3]

# %%
df = df[['ques','ans1']]

# %%
df['ans1'] = df['ans1'].replace(("Yes","No"),(1,0))

# %%
df = df.astype(str)

# %%
corpus = []
from nltk.corpus import stopwords
import re
def clean_data(sentence):
    sentence = sentence.replace('&#039;','"').replace("<br>"," ").replace("&quot;","'")
    sentence = re.sub('[^a-zA-Z]',' ',sentence)
    sentence = sentence.lower().split()
    words = [word for word in sentence if not word in stopwords.words('english')]
    sentence = ' '.join(words)
    corpus.append(sentence)

# %%
df.shape
# Out:
# (11089, 2)

# %%
df.columns = ['Comment','Cyberbullying?']

# %%
for sentence in df['Comment']:
    clean_data(sentence)

# %%
len(corpus)
# Out:
# 11089

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
from sklearn.model_selection import train_test_split
y = df.iloc[:,-1].values.astype(int)
print(y[0:5])
X_train,X_test,y_train,y_test = train_test_split(corpus,y,test_size=0.2,random_state=0)
# Out:
# [0 0 0 0 0]

# %%
cv.fit(X_train)
X_train = cv.transform(X_train)
X_test = cv.transform(X_test)

# %%
X_train = X_train.toarray()

# %%
X_test = X_test.toarray()

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

# %%
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = clf.predict(X_test)

# %%
score = accuracy_score(y_test,y_pred)

# %%
score
# Out:
# 0.9693417493237151

# %%
def pre(words):
    words = cv.transform(words).toarray()
    prediction = clf.predict(words)
    return prediction

# %%
pre(['shit talkin'])
# Out:
# array([0])

# %%
corpus
# Out:
# ['favorite song',
#  '',
#  'hey angel duh sexy',
#  '',
#  'meowww',
#  'makeup tips suck makeup lol',
#  'apriiiiiiiiiiiill miss uuuu emma btw haha',
#  'morning night person',
#  'trusting person',
#  'trusting person',
#  'truace best friends',
#  'talker listener',
#  'yuh single ready mingle',
#  'ask something',
#  'bahahahaha took longer enough p gees girl hahah totally okay wanted play guess hahaha fuckinggg love',
#  'bahahahahhaha p',
#  'please sing cover justin bieber song',
#  'cats dogs',
#  'chocolate vanilla',
#  'definitely true learnin years cuz frensh origins haha',
#  'u watch bieber oprah',
#  'believe life death',
#  'believe luck',
#  'believe intelligent life planets',
#  'consider good dancer',
#  'bf',
#  'favorite youtube star',
#  'memories like forget',
#  'piercings',
#  'scars body get',
#  'like atlanta ga',
#  'think size fat trying size end year',
#  'think good friend',
#  'watch american idol voting season',
#  'yuh stalkers',
#  'listen haters pretty',
#  'favorite store',
#  'fuck justin bieber fucking fag',
#  'growl',
#  'guesss',
#  'haa guessedd righhtttt dr maryyyy ahhh ilovee picture mayb becuase youhr babe',
#  'haaa qud sorry abouht hoe thinq iwas mad lol',
#  'haha u ever france',
#  'haha check inside ur closet u mind find',
#  'haha nope im taquisha either talk alot twitter',
#  'hahah guess',
#  'hahah okey dokey sweet thang',
#  'hahaha nope',
#  'u seen justin bieber person',
#  'broken bones',
#  'ever itellyouthat com go tell something world',
#  'ever heart broken',
#  'hehe yup awesome pronunciation incredibly haaard',
#  'hello friend also named april',
#  'hello',
#  'hellz yeahh course qoinqq wannah b quy like duhh',
#  'hey name april haha people named april always cool lol',
#  'hey amazing nice sweet girl pretty',
#  'hey bitch',
#  'heyyy abrilll iloveyhuuu muchooo',
#  'heyyyyyy u doin',
#  'heyyyyyyyy wats',
#  'hi april',
#  'many languages u speak',
#  'would describe personality',
#  'would describe words',
#  'love hair',
#  'love youu chica',
#  'love youuuuuuu',
#  'speak english frensh little arabic cuz egypt lotta times',
#  'think ur pretty sorry',
#  'bored tell something funny lool',
#  'u live forever wat u live',
#  'could ask barack obama one question would',
#  'could ask george w bush one question would',
#  'could star athlete sport sport would pick',
#  'could invited one person birthday party whose would',
#  'could one tv show one would',
#  'could become fictional character would',
#  'could change name would change',
#  'could date celebrity would',
#  'could eat dinner person dead alive would would go',
#  'could eliminate one thing day bathroom never would',
#  'could go back time years tell younger self something would',
#  'could go road trip person dead alive would would go',
#  'could go vacation next month unlimited budget would go',
#  'could endless supply food would get',
#  'could author book would',
#  'could make one person fall love would',
#  'could master one skill would',
#  'could listen one song next month would',
#  'could read one magazine rest life would',
#  'could rid world one thing would',
#  'could wake anyone tomorrow would',
#  'cook dinner someone tonight would make',
#  'give one favorite food would difficult',
#  'talk show would first three guests',
#  'shopping spree store store would pick',
#  'million dollars would',
#  'house fire could grab three things would',
#  'ilove nose ring',
#  'ily',
#  'im good juz got bak srip vegas awesome luved hav u evah vegas',
#  'truace single',
#  'justin bieber driving teacher oohh yess bahah gonna sumthing else instead teaching drive lmao',
#  'lol oo guurrrl u must crazy b c love u muchoo',
#  'love baby',
#  'mammaasss haha go skype',
#  'miley amp bieber',
#  'nope im bianca either heres clue come new zealand lol',
#  'nopeee name starts b',
#  'oh visit travel world kthxbye xx',
#  'omg justin bieber haha',
#  'rate yurself',
#  'shut ur prettty',
#  'sneakers sandals',
#  'sooooooo srry late im juzz doin mothur freakin boring zzzzzz zzzz snore snore lmbo',
#  'girl background bottom right hand corner looks like anna maria perez de tagle',
#  'tht woul b cool u u',
#  'wat state u live',
#  'well dats tight ur friends wit truace feel kno since ur friend u wud kno hav gf',
#  'well u say language coba tebak ini bahasa apa kamu ngerti ngga aku ngomong apa',
#  'excited right',
#  'dream last night',
#  'u guys prefer jonas brothers justin bieber',
#  'think formspring far',
#  'think attractive feature',
#  'think greatest invention lifetime',
#  'kind glasses',
#  'kind music stand listen',
#  'music listening today',
#  'one thing exceptionally good',
#  'tv show wish would go air good',
#  'best concert went',
#  'happiest moment life',
#  'last book read',
#  'worst advice ever received',
#  'worst concert went',
#  'worst job ever',
#  'favorite birthday gift',
#  'favorite year',
#  'worst travel experience',
#  'website spend time',
#  'would best workplace perk',
#  'would perfect day look like',
#  'one food never eat',
#  'one thing probably throw away never',
#  'best gift ever given',
#  'best place near get drink',
#  'best place near get ice cream',
#  'best place near get ice cream',
#  'furthest ever traveled',
#  'longest ever gone without bath shower',
#  'delicious meal ever',
#  'origin name',
#  'weirdest thing ever eaten',
#  'weirdest thing ever eaten',
#  'best achievement',
#  'biggest phobia',
#  'dream car',
#  'earliest memory',
#  'fave song',
#  'favorite drink',
#  'favorite food',
#  'favorite genre music',
#  'favorite movie quote',
#  'favorite type flower',
#  'favourite colour',
#  'favourite movie',
#  'yur fav color',
#  'whats ur fav tv showww',
#  'ever go google translate dont use trust',
#  'last time gave flowers',
#  'kid want grew',
#  'ya',
#  'would like spend retirement',
#  'would like live',
#  'ideal holiday destination',
#  'first kiss',
#  'top three celebrity crushes',
#  'twitter besties',
#  'decided take shit face',
#  'think next president united states',
#  'best teacher ever',
#  'funniest person know',
#  'famous person met',
#  'overrated athlete',
#  'prettiest person know',
#  'sexiest woman alive',
#  'u follow bandwagon formspring twitter next gay justin beiber',
#  'woaahhhhhh likee dude youhr backround awesomeeee ilybbyy',
#  'would u ever go bungee jumping like justin',
#  'would rather famous musician famous actor',
#  'would rather vampire werewolf',
#  'would rather zombie mummy',
#  'would rather rich famous',
#  'would rather date lot different people committed relationship',
#  'would rather get early sleep late',
#  'would rather luxury yacht private jet',
#  'would rather swim pool ocean',
#  'would rather work large company small one',
#  'yea different warm cali cool weeeell gtg gonna meet friends minutes lol bye xx',
#  'yeh r right bf',
#  'yooooo mate rinnalovesjb heyhey ask anything',
#  'attitude fun',
#  'nada',
#  'lol freaking way btw didnt ask',
#  'ahhh true true plus plays music xd',
#  'give one favorite food would difficult',
#  'pshhh liar',
#  'eat breakfast today',
#  'think attractive feature',
#  'one thing live without right',
#  'biggest accomplishment',
#  'favorite birthday gift',
#  'best place near get drink',
#  'favourite part watch rent',
#  'find formspring',
#  'ur first kiss',
#  'u perfect',
#  'wearing p',
#  'boyfriend',
#  'come party tonightt',
#  'damn hate shiiiit talkers formspringgg thought random question site thing',
#  'heart youu',
#  'lovee joiee',
#  'wub joie',
#  'jon person u like',
#  'joie beautifulllll',
#  'joiieeeee lalalovee youu',
#  'lmao yurr reall funny skinny ass bitchh hm really much insult fat lol u suck talkn shit later white trash skank ur super ugly nd guy u like really isnt gonna come back around u laterrrr',
#  'lol cute u friends back u doesnt matter ur still fake bitch go find real bf someone ur league lol ugly ass',
#  'piratee ninja ahah',
#  'really travis',
#  'shit talkin bitch',
#  'still bitch',
#  'uhm think love freaking joie thasss right',
#  'think attractive feature',
#  'favorite drink',
#  'like',
#  'ur lover',
#  'talented person know',
#  'whyy aree youu suchh aa faggottt',
#  'sexxyy mommma',
#  'ugly',
#  'love beautiful wanna boyfriend',
#  'one information wtf life best think twice try steal stuff bitch',
#  'show face anonymous wtf make sense fake ugly bitch',
#  '',
#  'girls belly dance r guys break dance',
#  'say lmfaoo well fake everyone knows need go sayoonarra',
#  '',
#  'im sorry im one fake lady lol comeon damn self im fucking mental know js means think need stfu get damn life instead beng faking girl btw nice comeback',
#  'fake though makes sense lolol would keep faking formsprings stuuupid p know real ashlee girls formspring already soo fuck may',
#  'wow ashleeee fakes amuse lmao okay retarded keep page upp',
#  'im sexy fucking ass duuude made laugh fucking hardd thank making day',
#  'r perfect age learn suck dick give hand jobs',
#  'call',
#  'ahaha mom dead thanks ugly ass bitch body knows life talk shit formspring pretty girls jelouse alright bitch',
#  'called fat',
#  'fat',
#  'good hangman suck',
#  'ready start school',
#  'single',
#  'ashlee biggest crush awhile go lot please message www findersingle com username wishfulthinker please get weird',
#  'ask anythinclude user info ing',
#  'baha actually im going go bitch fucking stupid real ashlee proof video dumb probably old man behind computer screen go fuck',
#  'basicc information name age location grade',
#  'best lil wayne song',
#  'best thing happened summer',
#  'betty like adorable look like crack heads shit toilet dear',
#  'bitch stfu least recognize lyk u',
#  'bob',
#  'call tomorrow',
#  'chicken hamburgers',
#  'cuter',
#  'cyrus',
#  'know',
#  'words really hurt',
#  'curse',
#  'hate people give short boring answers questions',
#  'know anyone almost anything attention',
#  'like adtf',
#  'like bodtf',
#  'like nevershoutnever',
#  'like clean',
#  'like name',
#  'love twilight much bet new homepage http mytwilightsearch com',
#  'miss hometown',
#  'think could make woods camping supplys week cellphone',
#  'bother strangers try tell',
#  'bedroom door lock',
#  'call bitch vv',
#  'hate people make fake celerbity pages',
#  'dont hate people dating days put love persons name statuses stuff',
#  'dude serious stupidddd stfu btw tired people talking shit form spring delete accountt bad',
#  'dude seems like everyone hates delete socialing sites',
#  'ever gang',
#  'ever dyed hair many times',
#  'everyone look girl using missy lockes pictures told fake like im fake took bettys pictures shes dumb http www formspring lmt',
#  'ew gross ugly bitch',
#  'faaaaake',
#  'fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake fake',
#  'faveee timee sport',
#  'favorite band',
#  'favorite color',
#  'favorite song',
#  'favorite song',
#  'favve song',
#  'get life twisted bitch',
#  'girls cheered guys played football',
#  'girls ever faught guy happened guys girl ever faugh happened',
#  'go hell xd',
#  'grosss face nasty',
#  'grosss face nasty',
#  'guess get life even know would even start shit seriously must bit messed head pathetic',
#  'guys hate girls girls hate guys',
#  'haha lifeless cunt stop writing wall shit faced slut',
#  'ever georgia',
#  'ever hated loved someone',
#  'heey many formsprings u like damn get life',
#  'hello',
#  'hey cousin coming visit us gonna make formspring',
#  'hey everyone girl fakes ta',
#  'hey dont go kill alot ppl would really happy',
#  'heyyy ugly fucking bitch think sexy haha shit besides ugly bitch amp beware ill fucking put shit blast fucking stupid ass cunt fuck amp stop hatein peoples pages go ugly ass',
#  'hi smelly rotten poo smell like pigs vomit go toilet wondered smell missed toilet fell ugly clothes poor stink like hamster poo love ram metal pole ass',
#  'hi',
#  'hi',
#  'hmm questionss inbox ideas',
#  '',
#  'mom',
#  'many siblings',
#  'many silly bands',
#  'often go salon get something done hair',
#  'old',
#  'http files formspring profile bea ca thumb jpg',
#  'dont know seem like bitch',
#  'found jensens thingie cant really see picture guess cute',
#  'hate formspring messes',
#  'hate people mad reason',
#  'hope asswhole gets sniffed aids',
#  'know amazing singer jeremy mckinnon soooooo funny loved giving high fives shirt cool fat guy lol know band august burns red',
#  'like everyone writes insult seriously questions dissing hahah',
#  'like yur bg',
#  'love adtr vvv fav know every song heart',
#  'never said sexy dumbasssssss',
#  'really wanna take downn song lmfaoo',
#  'swear fucking god bitch hate much think add people talk shit pages haha naaa yuuu must got us fucked im going hunt ass beat shit youu hands kbitchhhh',
#  'creepy stalker everyone fucking hates everyone knows fucking remind harmony flashpink uglier alittle pathetic everyone knows fake girls want attention dumbfuck',
#  'fake r sorry',
#  'perform circus trick would',
#  'im big fan betty u ugler fuck bitch u ugly shit head',
#  'im bored',
#  'anyone wish never met',
#  'cool swear',
#  'lala',
#  'learn spell learn tell apart typo spelling error learn proper fake',
#  'lmfao fucking creepy amp must friends life create muliple formsprings saying theyre fakes quit thinking everyone wants amp copy one would fake sorry pathetic poser',
#  'lyrics killed chance adtr',
#  'body likes yuuuuuuu',
#  'honestly really immature',
#  'nom nom',
#  'nope actually life coughcough unlike lonely pathetic ugly lowlife man woman life events staying formspring creating fakes starting shit seriously bitch end story kcoolbye',
#  'oh well met abr singer shit beast',
#  'ohh look girl fakes',
#  'okae bitch dont got quick comebacks fucking fake',
#  'online',
#  'pretty gurrrl',
#  'relation miley cyrus',
#  'stfu hoe piece shiit',
#  'stop leaving stuff like fake formsrping dead give away dumbass suck cunt',
#  'stop making fakes ugly fuck actually bitch deff cyrus get mother fucking life cunt',
#  'thats think right gimme ideas amp ask stuff',
#  'u know u care betty way better looking u',
#  'ugly piece shit',
#  'ugly',
#  'uhm right vvvvvvv dumbfuck stop starting shit everyone kcoolbye',
#  'well crude',
#  'going hahaha going haha im going get bitchess kick living shit ugly fake wanna bitch made ass',
#  'plans weekend going miami',
#  'color eyes',
#  'lunch',
#  'think bed last night',
#  'like best formspring',
#  'lol mean',
#  'hell',
#  'website spend time',
#  'nicest thing someone ever done',
#  'quickest fell someone',
#  'favv waterpark go',
#  'whats last thing going bed',
#  'whats wierdest color ever dye hair',
#  'whats ur myspace page',
#  'whats favorite silly band shape',
#  'school start mine starts aug th',
#  'drop phone get scared broke',
#  'born also grow',
#  'pays phone bill',
#  'still alive',
#  'fake lameeee know like lot hate groups myspace',
#  'ashlee',
#  'say nope oh leave people alone delete fucking fake',
#  'worst place eat',
#  'would sex fat guy',
#  'would kiss last person talked phone',
#  'would rather parents watch sex preacher beginning end lmao',
#  'wow fucking fake tired everyone talking shit formspring either stop talking shit first delete damn thing gosh fucking retarded forgot stupid people days would',
#  'wow fucking stupid told girl whoo info showing show face anonymus comebacks fucking suck fighting internet like special olympics even win still retarded',
#  'wow',
#  'xdfcvghjkl',
#  'u big nose seriously girl big nose',
#  'yeah met show got free shirt',
#  'yeauh really liar cool r lie stupid reasons',
#  'stupid ugly',
#  'dont even fucking fakes stop fucking bullshit get life jezuss old kid lifeless bitch need help',
#  'drunk',
#  'got myspace',
#  'guys funny answers read peoples answers questions like',
#  'never called',
#  'come next week',
#  'die',
#  'ignore comments people send everyone knows fake want like pretty know jealous cousin',
#  'sure hell look like dog fucking call hun got',
#  'fucking pathetic',
#  'one ugliest bitches ever fucking seen',
#  'bitch fuck',
#  'fake fake calling real hailey fake formspring lame bitch',
#  'fuckin ugly bitch look like man face',
#  'come backs fucking horrible dumb bitch wtf like fucking five like know yeahhhh bitch get fucking life',
#  'face nastyy',
#  'mad ugly true talk',
#  'fucking pretty stop hating grace pretty girls jealous omg',
#  'probably one faking kai huh fucking bitch',
#  'fucking immature sorry friends rude everyone',
#  'ugly fuuuuck betty prettier youuu stopp bitchhh',
#  'ugly',
#  'iloveyoubaby iloveyoutoobabygirl haha x',
#  '',
#  'c u l l want himm hush',
#  'ahaa late already sent youu onee',
#  'ahahaahahahaha yourr funny kid',
#  'ahh cutee',
#  'alright cool',
#  '',
#  'would fight jst asken',
#  'andrew stop talking friends nobody likes think hot shit thats whats annoying bye failed rapist',
#  'anyone someone particular',
#  'u guus foing yet',
#  'lindsey talking',
#  'foing',
#  'saying would fight lindsey lot people would first challenge',
#  'arent u guys going',
#  'asshole',
#  'aw see even nico nott want go near like try typeall ghetto dont fucking scare bitch ill fucking kill faught probably bring ghetto friends bahahaha would bella kendall pff',
#  'aww beat ass badass enough exactly imeant pussssssyss',
#  'think asked wants boyfriend find rest',
#  'bullllllllll ahah',
#  'says right cant',
#  'cute',
#  'dickkkkkkkkkkkkkk',
#  'u ever like tayler philips',
#  'u wanna get raped hehe',
#  'think girls look better makeup none',
#  'want girlfriend',
#  'want another hint',
#  'look like give flying fuck',
#  'dudde ima fuuck til bleed',
#  'dude fucken fagget ahahaha',
#  'ew wuld never jelous ur life coke yup thats drug u still seem handle lot one gives flying fuck ur life leave andrew fuck alone bc u hate firey cunt',
#  'ew vvvvvvv',
#  'exactly ur hard get fuck urself',
#  'frances seriously stop trying make people feel bad ugly bitch',
#  'fuck im jealous ugly ass freak',
#  'ha would lovee heard im harassing youu big p maybe get know eachother could spend quality time togetherr hahaha',
#  'haha',
#  'haha connnnceidddddeddd much',
#  'haha damn ninja thing gave away',
#  'haha know tried make really obvious youu lol',
#  'haha keep saying shit ill kill',
#  'haha loserrr',
#  'haha haha iloveyouutoobabyy',
#  'haha nah know guess',
#  'haha fair p',
#  'haha ok',
#  'haha thanks would never named honerary ninja',
#  'haha thankz',
#  'haha guys freakss love tho',
#  'haha youu cute',
#  'happy',
#  'hello would like tell think soo perfect adorable liar totally kissable im pretty chance',
#  'hi name nico im total studd u',
#  'youu plan making birthday amazing',
#  'past couple days',
#  'cant tell would give away didnt know personally last year',
#  'didnt say u didnt',
#  'know personal level bitch',
#  'dont givafuck ur friendless previously stated one comments except firey bitch',
#  'guarantee guys wont going end summer',
#  'hate ur fucking guts u amp lindsey grossest thing ive ever seen',
#  'shit straight wears like shirts little pink white stripped shirt plaid blue red pink shirt whatever maybe random ones jeans shorts vans owned',
#  'hope fool like bomb fuck got body sry fo spellin ya name wrong lil mama',
#  'hope know hate frances one best friends ass hole',
#  'really sorry ishh page tho nico im gonna sit people talk shit thats raised im sorryy dont mean freeaking kinda cnt help',
#  'see still like frances',
#  'juuust saying hi',
#  'ill fight bitch',
#  'im girl',
#  'im ninja helps',
#  'im jewish im catholic suck dick',
#  'im one called whore either haha play soccer run track dance eight years gymnastics',
#  'problem',
#  'big deal',
#  'stuff handle imma big girl dont tripp',
#  'lets see amp amp born th ghetto si wtfuhh know bout tht cuhh ahaha damn thing get level trickk show name amp catchh ahh fade lil homiee amp know dont stay away come find bxtch',
#  'lmao v',
#  'lmfaoooooo jealous bitches make sick nicoo ahaah th fxck',
#  'lol funny kidd know',
#  'nah im joking',
#  'nah wish',
#  'nico martinez youu hott hahaha',
#  'nicoooo okay welllllll bye',
#  'thats formspring',
#  'hate taylor used b firey dyed hair',
#  'im thanks throwing',
#  'nope unfortunately',
#  'telling find probably hard though',
#  'wonder',
#  'oh frances hunny dont try talk ghetto white ass doesnt fucking scare break fucking half',
#  'oh well baddddd',
#  'ohh reallu well feel want',
#  'ohhh amp amp hes deffinately drowning',
#  'r u amp frances still talken',
#  'say face trick ass nigga fxckin murder aint tryna make body feel bad hush got something say please step amp amp show namee fuckinn bitch whuss',
#  'school kinda',
#  'sext',
#  'shira frances',
#  'talking shira frances hard keep playa playaa lol',
#  'whats',
#  'whats',
#  'like',
#  'said way like hour ago live like min away youu',
#  'wont lol forgot ending goes like would could cant wont',
#  'text right',
#  'sorry funny playa playa ahah p',
#  'thanks though appreciate',
#  'gonna first hint guess knew obvious',
#  'thats lie',
#  'thats thought haha',
#  'chicken flies midnight tell anyone',
#  'late hate',
#  'vv excuse anonymous spell name p welcome hahaha',
#  'well put two cents haha',
#  'well put',
#  'well thats bad',
#  'youu talking gayy boyyu idid textt back didnt text back',
#  'mean drama cause',
#  'want ask something inappropriate',
#  '',
#  'whatever im gunna leave guys cry amp get hurt mean begging leave bye pussys',
#  'two people',
#  'bestfriend',
#  'whore',
#  'wtf v',
#  'yeah go ahead play victim know nico thats know player',
#  'yeah know ha thanks hun',
#  'yeah really hard get shit like every ither day like seriously pisses like yesturday wouldnt give fucks everything im going thru right like wtf',
#  'yeahh im convo th nextt onee ahahaha hello',
#  'yo dawg herd u like cans put yo',
#  'frances gross nastiest couple ive ever freakin seen way league like joke',
#  'welcome',
#  'ask shes still feelin know sure',
#  'tell p',
#  'youd fight lindsey im gurl id love see',
#  'fagggggg',
#  'mighty attractive',
#  'bitch ill kill nigga',
#  'still gay bitch haha',
#  'one talkin shit back fuckstick mean seriously th grade get',
#  'yup yup grade',
#  'yuppp',
#  'helloooo',
#  'amp amp anyone gets tired questions generally annoyed spammed please let know bother anyone thank',
#  'musta mooosta filipino word w c means musta',
#  'r cools ilike pikk lols',
#  'save life would ever give mouth mouth person herpes',
#  'one bothering bit seem like everyone wants knwo world end going fear till like k',
#  'poof prison',
#  '',
#  'currently happy life right',
#  'physical features get complimented lot name least favorite feature',
#  'physical features get complimented lot',
#  'things mom know',
#  'favorite things eat',
#  'car broken side road stop help',
#  'world without bees good bad',
#  'ability fly breath water',
#  'many pairs jeans',
#  'actually ihdontmind goahead',
#  'viewing said video footage sees next',
#  'dream mostly wake remembering',
#  'alvin simon theodore',
#  'always wear seat belt',
#  'interesting question asked get hobo statement lol',
#  'last q moment duck tape made ducks',
#  'prue amp phoebe charmed came robots came back amp run boy saved lol random',
#  'living grandparents',
#  'new exciting news youu like share',
#  'plans become doctor someday',
#  'anything parents know',
#  'children act r rated movies allowed see',
#  'dollar stores cool',
#  'minors allowed drink state',
#  'dreams realistic feels like actually happen real life non realistic flying',
#  'questions boring',
#  'best things life free',
#  'bruises body',
#  'people youtube subscribe always watch vids',
#  'u virgin',
#  'filipina foreigner',
#  'friendly person',
#  'generous person',
#  'good painter',
#  'happy person',
#  'leader follower',
#  'party girl',
#  'private person openly share life people around',
#  'registered voter',
#  'risk taker yes kind risks taken',
#  'sore loser',
#  'tease haha',
#  'touchy feely person',
#  'afraid heights',
#  'afraid snakes',
#  'always trying learn new things',
#  'awaiting piercings tattoos',
#  'barefooted right',
#  'better today yesterday',
#  'carrying grudges',
#  'currently taken',
#  'currently wanting piercings tattoos',
#  'double jointed',
#  'due sometime year doctor visit',
#  'easily offended',
#  'easily persuaded argument',
#  'eating anything right',
#  'frightened spiders',
#  'gonna watch world cup',
#  'good giving directions',
#  'happy life right',
#  'happy',
#  'college course taking',
#  'involved romantically anyone right',
#  'listening music right',
#  'loud quite',
#  'proton neutron',
#  'nice people dislike',
#  'obsessed shiny things',
#  'one people doesnu like chocolate',
#  'passionate beliefs',
#  'picky spelling grammar',
#  'picky spelling grammar',
#  'quick take medicine likely wait',
#  'random predictable think way would rather way',
#  'scared lose person fell hardest still person already lost',
#  'sick hearing michael jackson yet',
#  'silly serious',
#  'love',
#  'someone best friend',
#  'still shy talk sex',
#  'stubborn',
#  'studying working',
#  'telling truth lie bed',
#  'ideal person want would',
#  'kind friend would want friend',
#  'person want',
#  'person want',
#  'vain',
#  'vegetarian',
#  'willing travel dream job',
#  'working',
#  'days full fastu paced',
#  'dreams mostly sweet bad',
#  'parents facebook',
#  'underwear socks folded drawer thrown',
#  'underwear socks folded drawer thrown',
#  'yu shy yu first meet people yu one always sparks conversation',
#  'kid collection anything shayla pawpaw buys kids harley shirt every store stops',
#  'soon turned computer website go first',
#  'aww coolr yew seem cool',
#  'honest song ozzy osbourne library',
#  'beautiful background shay agrees r worst habit',
#  'beetles taste like apples still like apples',
#  'atheist means dont need believe choose believe either proof god done nothing us may believe god believe good reason believe exists',
#  'besides english languages speak',
#  'besides country currently live country want spend rest life',
#  'man woman cheats',
#  'boxers briefs boxer briefs lol',
#  'bright room dark room',
#  'bugs bunny mickey mouse',
#  'camping ton friends hotel friends',
#  'bald men get lice',
#  'crop circles square',
#  'get encore want',
#  'someone honestly thinking nothing think possible could',
#  'u name animal orange',
#  'two places',
#  'cook',
#  'cross eyes',
#  'cartwheel',
#  'push ups',
#  'draw pictures well',
#  'drive manual shift vehicle',
#  'drive motorcycle',
#  'go underwater without holding nose',
#  'name one person first last initials',
#  'pls ask questions',
#  'ride horse',
#  'roll tongue',
#  'see halo',
#  'skip rocks',
#  'sleep jeans',
#  'sometimes finish someone else sentence',
#  'tell someone lying',
#  'tie shoes one way',
#  'cheesecake brownies pick one rest life',
#  'cheetos fritos',
#  'chocolate vanilla',
#  'cleveland',
#  'close eyes count went mind honest',
#  'comedy horror movies',
#  'concert went never forget',
#  'cooool riddleee dr gooogleeee find',
#  'could would eat caterpillar',
#  'could ever shoot someone trying kill',
#  'could go public looking like',
#  'could visit comment u bfpodru edais visitar mi blog u bfquu e os parece http contandolospetalos blogspot com',
#  'current worry',
#  'current worry',
#  'cute default',
#  'define bitch haha',
#  'describe perfect guy',
#  'describe first real date',
#  'describe perfect day',
#  'describe words',
#  'describe single sentence',
#  'ever smell ur feet',
#  'timmy fun',
#  'watch heroes favorite character favorite power',
#  'celebrate r lol',
#  'believe tooth fairy',
#  'school shopping yet',
#  'ever get trouble talking class',
#  'ever go summer camp',
#  'ever crush never acted',
#  'ever embarrassing moment school',
#  'ever play duck duck goose child',
#  'get questions cause flooding past days',
#  'good day',
#  'fun weekend',
#  'help someone today',
#  'know gaga episode mtvs boiling point',
#  'know gullible written ceiling',
#  'make fun people school',
#  'remember get rings earrings dresser',
#  'still want job kid',
#  'talk someone fell asleep last night',
#  'wink today',
#  'listen parents',
#  'close friends children',
#  'friends children',
#  'friends children',
#  'cats psychic powers control babys minds tell take bahamas control worlds supply milk',
#  'certain peoples lives certain worth prostiture killers ect',
#  'humming birds hum dont know words',
#  'people know u nickname first name',
#  'people australia call rest world',
#  'peoples words bother',
#  'strangers try talk one old drunk dude struck convo xen store',
#  'alphabet song twinkle twinkle little star tune',
#  'makers friendster uses facebook',
#  'wear vans shoes',
#  'play instrument',
#  'also like diary wimpy kid',
#  'always trust instinct',
#  'always wear watch',
#  'timmy ki pass',
#  'answer phone calls know number',
#  'ask questions sometimes really want answer',
#  'believe honesty best policy',
#  'believe aliens',
#  'believe angels demons',
#  'believe fate',
#  'believe karma destiny',
#  'believe love',
#  'believe quote sleep im dead',
#  'believe sometimes life selfish',
#  'believe everything happens reason',
#  'believe god gender',
#  'believe guy pay first date',
#  'bite lip lot',
#  'buy things online',
#  'chew pens pencils',
#  'close eyes sneeze',
#  'conform make path',
#  'consider animal lover',
#  'consider creative',
#  'crack knuckles',
#  'cry often keep inside',
#  'cry often keep inside',
#  'cuss',
#  'dance shower',
#  'dance shower',
#  'daydream sometimes often daydream',
#  'de label beer bottles',
#  'needs done regardless consequences',
#  'dishes',
#  'dream color',
#  'eat lot',
#  'eat servings food groups daily basis',
#  'eat weird mixture foods',
#  'eat breakfast daily',
#  'eat cheeseburgers',
#  'eat jello sick',
#  'enjoy giving hugs',
#  'enjoy going shopping type things enjoy buying',
#  'ever count steps walk',
#  'ever go bird watching',
#  'ever take medication help fall asleep faster',
#  'ever think humans satisfied',
#  'ever think amazing song something wonder would still big released first time',
#  'ever think becoming model',
#  'ever think crazy things head probably wont happen',
#  'ever think smile little',
#  'ever try impose beliefs others',
#  'excercise regularly often',
#  'fall asleep day cannot sleep night',
#  'fear respect law say',
#  'fear something honestly reason fear',
#  'feel children sheltered unhappiness',
#  'feel appreciated',
#  'feel weird around people know',
#  'find opposite sex confusing',
#  'generally believe people telly ou sorry question',
#  'get along better opposite sex',
#  'get along argumentative people',
#  'get annoyed people display bad manners',
#  'get annoyed someone cuts front waiting line',
#  'get cold sores often',
#  'get distracted easily',
#  'get excited cameras',
#  'get mad people lie',
#  'get nervous doctor appointments',
#  'get nervous alot people look',
#  'give easy sex wise play hard get',
#  'give second chances easily',
#  'give smart ass answers questiosn answer good answer',
#  'go buy first name middle name',
#  'go church regularly',
#  'guys like robot chicken asked',
#  'hate alone',
#  'hate last guy girl talking',
#  'calender room',
#  'cellphone ipod patterened cover',
#  'distinct smell',
#  'favorite beatles song',
#  'favorite jim carrey movie',
#  'fetish',
#  'pair underwear consistently gives wedgie yet still wear',
#  'secret one knows',
#  'song stuck head right',
#  'specific work routine keep shape mentally physically speaking',
#  'v bedroom',
#  'tan',
#  'tattoo located stand',
#  'concerns moment',
#  'fun summer plans',
#  'health problems',
#  'jewelery',
#  'magazine subscriptions',
#  'phobias',
#  'tattoos plans get one',
#  'weird habits',
#  'classes favorite subject',
#  'dreams becoming famous',
#  'one britney spears c',
#  'twitter',
#  'two formsprings following different account still haha',
#  'bank account',
#  'vehicle',
#  'twitter account',
#  'ignore people mad upset',
#  'judge people look like',
#  'know alcoholic',
#  'know drug addict',
#  'know mechanical stuff cars',
#  'know anyone prison',
#  'know anyone broken thigh bone know thigh bone stronger concrete',
#  'know anyone keeps dog house',
#  'know anyone adopted child',
#  'know anyone mental problem',
#  'know april',
#  'know much peso would worth united states today',
#  'know change tire change oil change spark plug',
#  'know knit',
#  'know play poker',
#  'know speak korean',
#  'know karate',
#  'know boricua moricua morena mean',
#  'know dad born',
#  'learn easy way hard way',
#  'leave voice messages',
#  'like alice wonderland',
#  'like beef jerky',
#  'like blue cheese',
#  'like broccoli',
#  'like candy necklaces',
#  'like care bears',
#  'like carrots',
#  'like cats',
#  'like dogs one',
#  'like hot cold showers',
#  'like hugging people meet uncomfortable',
#  'like people randomly come',
#  'like ketchup hate tomatoes',
#  'like ketchup',
#  'like kool aid',
#  'like lady gaga',
#  'like mustard',
#  'like nachos',
#  'like politics',
#  'like predictive text',
#  'like riding roller coaster',
#  'like shopping new clothes',
#  'like skittles',
#  'like movie chronicles narnia',
#  'like smell cigarettes',
#  'like smell weed',
#  'like sound wind chimes',
#  'like dress ordered earlier http www topshop com webapp wcs stores servlet productdisplay beginindex amp viewallflag false amp catalogid amp storeid amp categoryid amp parent category rn amp productid amp langid',
#  'like go rain',
#  'like touch sharp objects',
#  'like travel airplane',
#  'like tom cruise movies',
#  'like traveling often think ride car',
#  'like vitamin water',
#  'like wild parties lots people',
#  'like living arrangement',
#  'like name',
#  'like name',
#  'likee chicks',
#  'listen christian rock',
#  'listen music depending mood music make mood',
#  'listen music every day',
#  'listen mom',
#  'live china',
#  'loan people money',
#  'look quality quantity',
#  'look forward sleeping',
#  'love party',
#  'make jokes laugh',
#  'make bed daily',
#  'miss past',
#  'miss past',
#  'missed formspring',
#  'think think',
#  'bathrobe',
#  'gun would ever',
#  'pair dice',
#  'striped sweater',
#  'band tu shirts',
#  'game consoles',
#  'anything leopard print',
#  'anything involves betty boop',
#  'shirts funny sayings favorite',
#  'slippers',
#  'pay attention calories back packages',
#  'prefer chinese mexican',
#  'prefer hot coffee iced coffee neither',
#  'prefer regular chocolate milk',
#  'prefer scary movies comedy movies',
#  'prefer tape stapler',
#  'prefer ask question answer think',
#  'prefer blissfully unaware know going though may hurt know',
#  'prefer work independently team',
#  'put anything spaghetti bolognaise',
#  'put cheese spaghetti',
#  'put make everyday',
#  'put christmas lights christmas time',
#  'randomly bust singing hear song playing somewhere',
#  'read trashy romance novels often',
#  'really truly miss someone right',
#  'really care people think',
#  'recycle',
#  'regularly watch news',
#  'say love friends time',
#  'scream rollercoasters',
#  'shower morning night bed',
#  'shower morning night bed',
#  'shrug cry hours',
#  ...]
