# %%
from tensorflow.keras.layers import Dense,Embedding,LSTM,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import pandas as pd
import tensorflow as tf
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Fawaz\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('../../../formspring_data.csv',delimiter='\t',quoting=3)

# %%
df = df[['ques','ans1']]  #limiting to question and answer 
#replacing html symbols
df['ques'] = df['ques'].str.replace('&#039;',' ')
df['ques'] = df['ques'].str.replace('&quot;',' ')
df['ques'] = df['ques'].str.replace('<br>',' ')

# %%
df = df.dropna()
positives = df[df['ans1']=='Yes']
negatives = df[df['ans1']=='No']
frames = [positives,negatives]

# %%
df = pd.concat(frames)
df = df.sample(frac=1)

# %%
df['ans1'] = df['ans1'].replace(('Yes','No'),(1,0))
bag = []
def clean_data(sentence):
    sentence = re.sub('[^a-zA-Z]',' ',sentence)
    sentence = sentence.lower().split()
    words = [word for word in sentence if not word in stopwords.words('english')]
    sentence = ' '.join(words)
    bag.append(sentence)

# %%
df['ans1'].value_counts().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['ans1'].value_counts()
# Out:
# 0    11691
# 1     1038
# Name: ans1, dtype: int64

# %%
import re
df['ques'].apply(clean_data)
# Out:
# 6300     None
# 2777     None
# 7162     None
# 4458     None
# 2660     None
#          ...
# 4725     None
# 9883     None
# 10104    None
# 10500    None
# 1775     None
# Name: ques, Length: 12729, dtype: object

# %%
tokenizer = Tokenizer(num_words=20000)

# %%
X = df['ques'].values
tokenizer.fit_on_texts(X)
print(tokenizer.word_index)
# Out:
# {'you': 1, 'i': 2, 'a': 3, 'the': 4, 'to': 5, 'do': 6, 'what': 7, 'your': 8, 'is': 9, 'and': 10, 'it': 11, 'have': 12, 'in': 13, 'of': 14, 'u': 15, 'or': 16, 'are': 17, 'if': 18, 'would': 19, 'that': 20, 'like': 21, 'on': 22, 'me': 23, 'how': 24, 'be': 25, 'for': 26, 's': 27, 'ever': 28, 'my': 29, 'apos': 30, 'so': 31, 'why': 32, 'with': 33, 'who': 34, 'was': 35, 'think': 36, 'not': 37, 'r': 38, 'know': 39, 'lol': 40, 'when': 41, 't': 42, 'd': 43, 'love': 44, 'can': 45, 'one': 46, 'just': 47, 'about': 48, 'get': 49, 'but': 50, 'did': 51, 'up': 52, 'at': 53, '3': 54, 'this': 55, 'people': 56, 'im': 57, 'they': 58, 'go': 59, 'out': 60, 'ur': 61, 'all': 62, 'want': 63, 'were': 64, 'm': 65, 'there': 66, 'time': 67, 'someone': 68, 'now': 69, 'haha': 70, 'favorite': 
ked': 254, 'word': 255, 'bed': 256, 'seen': 257, 'little': 258, 'hair': 259, 'happy': 260, 'cause': 261, 'man': 262, 'very': 263, 'favourite': 264, 'real': 265, 'opinion': 266, 'hi': 267, 'cute': 268, 'cool': 269, 'around': 270, 'while': 271, 'parents': 272, 'talking': 273, 'play': 274, 'year': 275, 'show': 276, 'sure': 277, 'try': 278, 'actually': 279, 'drink': 280, 'explain': 281, 'those': 282, 'l': 283, 'y': 284, 'went': 285, 'b': 286, 'color': 287, 'ppl': 288, 'phone': 289, 'music': 290, 'getting': 291, 'without': 292, 'sleep': 293, 'asking': 294, 'after': 295, 'lot': 296, 'though': 297, 'thanks': 298, 'didnt': 299, 'describe': 300, 'makes': 301, 'relationship': 302, 'tabi': 303, 'called': 304, 'worst': 305, 'v': 306, 'wear': 307, 'age': 308, 'having': 309, 'happened': 310, 'ya': 311, 'read': 312, 'home': 313, 'our': 314, 'ill': 315, 'morni ...

# %%
len(tokenizer.word_index)
X = tokenizer.texts_to_sequences(X)
X = sequence.pad_sequences(X,maxlen=250)

# %%
y = df['ans1'].values.astype(int)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
model = Sequential()
model.add(Embedding(20000,120))
model.add(LSTM(120,dropout=0.2,recurrent_dropout=0.2))
model.add(Dense(1,activation='sigmoid'))

# %%
from tensorflow.keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
history = model.fit(X_train,y_train,batch_size=45,epochs=3,verbose=2,validation_data=(X_test,y_test))
# Out:
# Train on 9546 samples, validate on 3183 samples
# Epoch 1/3
# 9546/9546 - 467s - loss: 0.2834 - accuracy: 0.9160 - f1_m: 0.0149 - precision_m: 0.0264 - recall_m: 0.0143 - val_loss: 0.2323 - val_accuracy: 0.9240 - val_f1_m: 0.0376 - val_precision_m: 0.0845 - val_recall_m: 0.0255
# Epoch 2/3
# 9546/9546 - 452s - loss: 0.1925 - accuracy: 0.9336 - f1_m: 0.3579 - precision_m: 0.5834 - recall_m: 0.2921 - val_loss: 0.2283 - val_accuracy: 0.9299 - val_f1_m: 0.2575 - val_precision_m: 0.4167 - val_recall_m: 0.2010
# Epoch 3/3
# 9546/9546 - 421s - loss: 0.1330 - accuracy: 0.9522 - f1_m: 0.5911 - precision_m: 0.7421 - recall_m: 0.5384 - val_loss: 0.2624 - val_accuracy: 0.9233 - val_f1_m: 0.2712 - val_precision_m: 0.3735 - val_recall_m: 0.2305

# %%
loss, accuracy, f1_score, precision, recall = model.evaluate(X_test,y_test,batch_size=45,verbose=2)
# Out:
# 3183/3183 - 23s - loss: 0.2624 - accuracy: 0.9233 - f1_m: 0.2712 - precision_m: 0.3735 - recall_m: 0.2305

# %%
test_sentence = ['You are a stupid bitch']

# %%
def pre(sentence):
  seq = tokenizer.texts_to_sequences(sentence)
  padded_seq = sequence.pad_sequences(seq,maxlen=250)
  pred = model.predict(padded_seq)
  pred_actual = round(pred[0][0],2)
  result = "This sentence has a "+str(pred_actual)+" probability of containing cyberbullying content"
  print( result)

# %%
pre(test_sentence)
# Out:
# This sentence has a 0.93 probability of containing cyberbullying content

# %%
pre(['You are a terrible liar'])
# Out:
# This sentence has a 0.21 probability of containing cyberbullying content

# %%
pre(['Why are you stupid?'])
# Out:
# This sentence has a 0.64 probability of containing cyberbullying content

# %%
pre(['Hello How are you doing?'])
# Out:
# This sentence has a 0.02 probability of containing cyberbullying content

# %%
pre(['I"m going to kill you and your family'])
# Out:
# This sentence has a 0.05 probability of containing cyberbullying content

# %%
pre(['You are a punkass'])
# Out:
# This sentence has a 0.13 probability of containing cyberbullying content

# %%
pre(['you are a fucked up bitch !'])
# Out:
# This sentence has a 0.92 probability of containing cyberbullying content

# %%
from sklearn.metrics import roc_curve

# %%
y_pred = model.predict(X_test).ravel()

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
plt.plot(fpr_keras, tpr_keras, marker='.', label='ROC Curve',color='orange')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
def get_roc_area_and_rates():
    from sklearn.metrics import confusion_matrix,roc_auc_score
    tn, fp, fn, tp = confusion_matrix(y_test,results).ravel()
    true_positive_rate = (tp)/(tp + fn)
    false_positive_rate = (fp)/(tn + fp)
    area = roc_auc_score(y_test,results)
    print("ROC area ",area)
    print("True positive rate ",true_positive_rate)
    print("False positive rate ",false_positive_rate)

get_roc_area_and_rates()
# Out:
# ROC area  0.6129466742224521
# True positive rate  0.24497991967871485
# False positive rate  0.0190865712338105

# %%
results = []
for result in y_pred:
    if result > 0.5:
        results.append(1)
    else:
        results.append(0)
