# %%
from tensorflow.keras.layers import Dense,Embedding,Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import pandas as pd
import tensorflow as tf
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Fawaz\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('../../../formspring_data.csv',delimiter='\t',quoting=3)

# %%
df = df[['ques','ans1']]  #limiting to question and answer 
#replacing html symbols
df['ques'] = df['ques'].str.replace('&#039;',' ')
df['ques'] = df['ques'].str.replace('&quot;',' ')
df['ques'] = df['ques'].str.replace('<br>',' ')

# %%
df = df.dropna()
positives = df[df['ans1']=='Yes']
negatives = df[df['ans1']=='No']
frames = [positives,negatives]

# %%
df = pd.concat(frames)
df = df.sample(frac=1)

# %%
df['ans1'] = df['ans1'].replace(('Yes','No'),(1,0))
bag = []
def clean_data(sentence):
    sentence = re.sub('[^a-zA-Z]',' ',sentence)
    sentence = sentence.lower().split()
    words = [word for word in sentence if not word in stopwords.words('english')]
    sentence = ' '.join(words)
    bag.append(sentence)

# %%
df['ans1'].value_counts().sort_values(ascending=False).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['ans1'].value_counts()
# Out:
# 0    11691
# 1     1038
# Name: ans1, dtype: int64

# %%
import re
df['ques'].apply(clean_data)
# Out:
# 10292    None
# 7562     None
# 10311    None
# 1844     None
# 7032     None
#          ...
# 12803    None
# 6410     None
# 11446    None
# 9348     None
# 11161    None
# Name: ques, Length: 12729, dtype: object

# %%
tokenizer = Tokenizer(num_words=20000)

# %%
X = df['ques'].values
tokenizer.fit_on_texts(X)
print(tokenizer.word_index)
# Out:
# {'you': 1, 'i': 2, 'a': 3, 'the': 4, 'to': 5, 'do': 6, 'what': 7, 'your': 8, 'is': 9, 'and': 10, 'it': 11, 'have': 12, 'in': 13, 'of': 14, 'u': 15, 'or': 16, 'are': 17, 'if': 18, 'would': 19, 'that': 20, 'like': 21, 'on': 22, 'me': 23, 'how': 24, 'be': 25, 'for': 26, 's': 27, 'ever': 28, 'my': 29, 'apos': 30, 'so': 31, 'why': 32, 'with': 33, 'who': 34, 'was': 35, 'think': 36, 'not': 37, 'r': 38, 'know': 39, 'lol': 40, 'when': 41, 't': 42, 'd': 43, 'love': 44, 'can': 45, 'one': 46, 'just': 47, 'about': 48, 'get': 49, 'but': 50, 'did': 51, 'up': 52, 'at': 53, '3': 54, 'people': 55, 'this': 56, 'im': 57, 'they': 58, 'go': 59, 'out': 60, 'ur': 61, 'all': 62, 'want': 63, 'were': 64, 'm': 65, 'there': 66, 'time': 67, 'someone': 68, 'now': 69, 'haha': 70, 'favorite': 71, 'had': 72, 'no': 73, 'from': 74, 'any': 75, 'as': 76, 'could': 77, 'them': 78, 'p': 79, 'last': 80, '39': 81, 'most': 82, 'say': 83, 'we': 84, 'been': 85, 'life': 86, 're': 87, 'person': 88, 'thing': 89, 'an': 90, 'her': 91, 'really': 92, 'don': 93, 'name': 94, 'amp': 95, 'o': 96, 'dont': 97, 'good': 98, 'she': 99, 'does': 100, 'its': 101, 'will': 102, 'where': 103, 'questions': 104, 'many': 105, 'more': 106, 'make': 107, 'right': 108, 'going': 109, 'too': 110, 'some': 111, 'has': 112, 'back': 113, 'then': 114, 'should': 115, 'day': 116, 'girl': 117, 'tell': 118, 'something': 119, 'he': 120, 'best': 121, 'which': 122, 'feel': 123, 'much': 124, 'first': 125, 'sex': 126, 'see': 127, 'got': 128, 've': 129, 'ask': 130, 'll': 131, 'spam': 132, 'well': 133, 'off': 134, 'hey': 135, 'whats': 136, 'way': 137, 'by': 138, 'song': 139, 'fake': 140, 'still': 141, 'am': 142, 'friend': 143, 'hate': 144, 'being': 145, 'here': 146, 'question': 147, 'anyone': 148, 'only': 149, 'n': 150, 'anything': 151, 'xd': 152, 'other': 153, 'over': 154, 'believe': 155, 'things': 156, 'girls': 157, 'look': 158, '2': 159, 'oh': 160, 'friends': 161, 'talk': 162, 'never': 163, 'because': 164, 'their': 165, 'guys': 166, 'give': 167, 'bitch': 168, 'rather': 169, 'mean': 170, 'live': 171, 'night': 172, 'even': 173, 'pretty': 174, 'shit': 175, 'formspring': 176, 'take': 177, 'stop': 178, 'today': 179, 'come': 180, 'than': 181, 'kind': 182, 'old': 183, 'movie': 184, 'said': 185, 'better': 186, 'yourself': 187, 'school': 188, 'need': 189, 'fuck': 190, 'lmao': 191, 'answer': 192, 'before': 193, 'guy': 194, 'everyone': 195, 'made': 196, 'find': 197, 'yu': 198, 'always': 199, 'down': 200, 'done': 201, 'http': 202, 'let': 203, 'wanna': 204, 'date': 205, 'own': 206, 'ass': 207, 'call': 208, 'world': 209, 'told': 210, 'eat': 211, 'new': 212, '1': 213, 'watch': 214, 'ok': 215, 'put': 216, 'long': 217, 'thats': 218, 'yeah': 219, 'same': 220, 'gonna': 221, 'sorry': 222, 'nice': 223, 'doing': 224, 'bad': 225, 'him': 226, 'com': 227, 'please': 228, 'place': 229, 'yes': 230, 'wish': 231, 'fucking': 232, 'into': 233, 'baby': 234, 'work': 235, 'change': 236, 'hot': 237, 'ugly': 238, 'use': 239, 'www': 240, 'miss': 241, 'yo': 242, 'big': 243, 'thought': 244, 'okay': 245, 'food': 246, 'car': 247, 'choose': 248, 'leave': 249, 'often': 250, 'asked': 251, 'next': 252, 'again': 253, 'saying': 254, 'bed': 255, 'word': 256, 'seen': 257, 'little': 258, 'very': 259, 'cause': 260, 'real': 261, 'hair': 262, 'favourite': 263, 'happy': 264, 'man': 265, 'opinion': 266, 'cute': 267, 'hi': 268, 'cool': 269, 'while': 270, 'around': 271, 'year': 272, 'play': 273, 'parents': 274, 'talking': 275, 'show': 276, 'actually': 277, 'sure': 278, 'try': 279, 'drink': 280, 'those': 281, 'explain': 282, 'y': 283, 'went': 284, 'l': 285, 'color': 286, 'sleep': 287, 'getting': 288, 'phone': 289, 'music': 290, 'b': 291, 'ppl': 292, 'without': 293, 'after': 294, 'asking': 295, 'lot': 296, 'though': 297, 'didnt': 298, 'makes': 299, 'describe': 300, 'thanks': 301, 'relationship': 302, 'tabi': 303, 'wear': 304, 'v': 305, 'having': 306, 'worst': 307, 'age': 308, 'called': 309, 'ya': 310, 'happened': 311, 'ill': 312, 'home': 313, 'read': 314, 'our': 315, 'stuff ...

# %%
len(tokenizer.word_index)
X = tokenizer.texts_to_sequences(X)
X = sequence.pad_sequences(X,maxlen=250)

# %%
y = df['ans1'].values.astype(int)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
model = Sequential()
model.add(Embedding(20000,120))
model.add(Dropout(0.2))
model.add(Dense(1,activation='sigmoid'))

# %%
from tensorflow.keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
history = model.fit(X_train,y_train,batch_size=45,epochs=3,verbose=2,validation_data=(X_test,y_test))
# Out:
# Train on 9546 samples, validate on 3183 samples
# Epoch 1/3
# 9546/9546 - 48s - loss: 0.3726 - accuracy: 0.9043 - f1_m: 0.3186 - precision_m: 0.2228 - recall_m: 4.8686 - val_loss: 0.2897 - val_accuracy: 0.9163 - val_f1_m: 0.4058 - val_precision_m: 0.3180 - val_recall_m: 0.7622
# Epoch 2/3
# 9546/9546 - 39s - loss: 0.2833 - accuracy: 0.9194 - f1_m: 0.8020 - precision_m: 0.6254 - recall_m: 1.4517 - val_loss: 0.2884 - val_accuracy: 0.9163 - val_f1_m: 0.4494 - val_precision_m: 0.3425 - val_recall_m: 0.8730
# Epoch 3/3
# 9546/9546 - 43s - loss: 0.2820 - accuracy: 0.9195 - f1_m: 0.8907 - precision_m: 0.6606 - recall_m: 1.6125 - val_loss: 0.2881 - val_accuracy: 0.9163 - val_f1_m: 0.4671 - val_precision_m: 0.3582 - val_recall_m: 0.9037

# %%
loss, accuracy, f1_score, precision, recall = model.evaluate(X_test,y_test,batch_size=45,verbose=2)
# Out:
# 3183/3183 - 1s - loss: 0.2881 - accuracy: 0.9163 - f1_m: 0.4671 - precision_m: 0.3582 - recall_m: 0.9037

# %%
test_sentence = ['You are a stupid bitch']

# %%
y_pred = model.predict(X_test)

# %%
results = []
for x in y_pred:
  results.append(x[-1][0])

# %%
import numpy as np
results = np.array(results)

# %%
results
# Out:
# array([0.06942049, 0.13043033, 0.07787974, ..., 0.0550433 , 0.24228247,
#        0.05470943], dtype=float32)

# %%
from sklearn.metrics import roc_curve
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, results)

# %%
import matplotlib.pyplot as plt
plt.plot(fpr_keras, tpr_keras, marker='.', label='ROC Curve',color='orange')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
result = []
for a in results:
    if a> 0.5:
        result.append(1)
    else:
        result.append(0)

def get_roc_area_and_rates():
    from sklearn.metrics import confusion_matrix,roc_auc_score
    tn, fp, fn, tp = confusion_matrix(y_test,result).ravel()
    true_positive_rate = (tp)/(tp + fn)
    false_positive_rate = (fp)/(tn + fp)
    area = roc_auc_score(y_test,result)
    print("ROC area ",area)
    print("True positive rate ",true_positive_rate)
    print("False positive rate ",false_positive_rate)

get_roc_area_and_rates()
# Out:
# ROC area  0.5637151672461922
# True positive rate  0.14285714285714285
# False positive rate  0.015426808364758314
