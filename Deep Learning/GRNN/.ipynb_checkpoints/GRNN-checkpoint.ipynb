# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
import tensorflow as tf
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Fawaz\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = pd.read_csv('../../../formspring_data.csv',delimiter='\t',quoting=3)

# %%
df = df[['ques','ans1']]  #limiting to question and answer 
#replacing html symbols
df['ques'] = df['ques'].str.replace('&#039;',' ')
df['ques'] = df['ques'].str.replace('&quot;',' ')
df['ques'] = df['ques'].str.replace('<br>',' ')

# %%
df = df.dropna()
positives = df[df['ans1']=='Yes']
negatives = df[df['ans1']=='No']
frames = [positives,negatives]

# %%
df = pd.concat(frames)
df = df.sample(frac=1)

# %%
df['ans1'] = df['ans1'].replace(('Yes','No'),(1,0))
bag = []
def clean_data(sentence):
    sentence = re.sub('[^a-zA-Z]',' ',sentence)
    sentence = sentence.lower().split()
    words = [word for word in sentence if not word in stopwords.words('english')]
    sentence = ' '.join(words)
    bag.append(sentence)

# %%
df['ans1'].value_counts()
# Out:
# 0    11691
# 1     1038
# Name: ans1, dtype: int64

# %%
import re
df['ques'].apply(clean_data)
# Out:
# 7251    None
# 8887    None
# 5994    None
# 7729    None
# 8873    None
#         ...
# 119     None
# 594     None
# 7956    None
# 2488    None
# 4768    None
# Name: ques, Length: 12729, dtype: object

# %%
tokenizer = Tokenizer(num_words=20000)

# %%
X = df['ques'].values
tokenizer.fit_on_texts(X)
print(tokenizer.word_index)
# Out:
# {'you': 1, 'i': 2, 'a': 3, 'the': 4, 'to': 5, 'do': 6, 'what': 7, 'your': 8, 'is': 9, 'and': 10, 'it': 11, 'have': 12, 'in': 13, 'of': 14, 'u': 15, 'or': 16, 'are': 17, 'if': 18, 'would': 19, 'that': 20, 'like': 21, 'on': 22, 'me': 23, 'how': 24, 'be': 25, 'for': 26, 's': 27, 'ever': 28, 'my': 29, 'apos': 30, 'so': 31, 'why': 32, 'with': 33, 'who': 34, 'was': 35, 'think': 36, 'not': 37, 'r': 38, 'know': 39, 'lol': 40, 'when': 41, 't': 42, 'd': 43, 'love': 44, 'can': 45, 'one': 46, 'just': 47, 'about': 48, 'get': 49, 'but': 50, 'did': 51, 'up': 52, 'at': 53, '3': 54, 'people': 55, 'this': 56, 'im': 57, 'they': 58, 'go': 59, 'out': 60, 'ur': 61, 'all': 62, 'want': 63, 'were': 64, 'm': 65, 'there': 66, 'time': 67, 'someone': 68, 'now': 69, 'haha': 70, 'favorite': 71, 'had': 72, 'no': 73, 'from': 74, 'any': 75, 'as': 76, 'could': 77, 'them': 78, 'p': 79, 'last': 80, '39': 81, 'most': 82, 'say': 83, 'we': 84, 'been': 85, 'life': 86, 'person': 87, 're': 88, 'an': 89, 'thing': 90, 'really': 91, 'her': 92, 'don': 93, 'name': 94, 'amp': 95, 'o': 96, 'dont': 97, 'good': 98, 'she': 99, 'does': 100, 'its': 101, 'will': 102, 'where': 103, 'questions': 104, 'many': 105, 'more': 106, 'make': 107, 'right': 108, 'going': 109, 'too': 110, 'some': 111, 'has': 112, 'back': 113, 'then': 114, 'day': 115, 'should': 116, 'something': 117, 'tell': 118, 'girl': 119, 'he': 120, 'best': 121, 'feel': 122, 'which': 123, 'much': 124, 'first': 125, 'sex': 126, 'see': 127, 'got': 128, 've': 129, 'ask': 130, 'll': 131, 'well': 132, 'spam': 133, 'off': 134, 'hey': 135, 'whats': 136, 'way': 137, 'by': 138, 'song': 139, 'fake': 140, 'still': 141, 'am': 142, 'friend': 143, 'hate': 144, 'being': 145, 'here': 146, 'question': 147, 'only': 148, 'anyone': 149, 'n': 150, 'anything': 151, 'xd': 152, 'other': 153, 'believe': 154, 'over': 155, 'things': 156, 'girls': 157, 'look': 158, '2': 159, 'oh': 160, 'friends': 161, 'never': 162, 'talk': 163, 'because': 164, 'their': 165, 'guys': 166, 'give': 167, 'bitch': 168, 'rather': 169, 'live': 170, 'mean': 171, 'night': 172, 'even': 173, 'pretty': 174, 'shit': 175, 'formspring': 176, 'take': 177, 'stop': 178, 'today': 179, 'than': 180, 'come': 181, 'kind': 182, 'old': 183, 'movie': 184, 'said': 185, 'better': 186, 'yourself': 187, 'need': 188, 'fuck': 189, 'school': 190, 'answer': 191, 'lmao': 192, 'before': 193, 'everyone': 194, 'guy': 195, 'made': 196, 'find': 197, 'yu': 198, 'down': 199, 'done': 200, 'always': 201, 'http': 202, 'date': 203, 'wanna': 204, 'own': 205, 'let': 206, 'ass': 207, 'told': 208, 'call': 209, 'world': 210, 'new': 211, 'eat': 212, '1': 213, 'watch': 214, 'put': 215, 'thats': 216, 'ok': 217, 'same': 218, 'yeah': 219, 'long': 220, 'sorry': 221, 'gonna': 222, 'nice': 223, 'doing': 224, 'bad': 225, 'com': 226, 'him': 227, 'please': 228, 'place': 229, 'fucking': 230, 'yes': 231, 'into': 232, 'baby': 233, 'wish': 234, 'hot': 235, 'www': 236, 'change': 237, 'work': 238, 'ugly': 239, 'use': 240, 'miss': 241, 'yo': 242, 'big': 243, 'thought': 244, 'okay': 245, 'food': 246, 'choose': 247, 'leave': 248, 'car': 249, 'often': 250, 'asked': 251, 'again': 252, 'saying': 253, 'next': 254, 'seen': 255, 'bed': 256, 'word': 257, 'little': 258, 'real': 259, 'man': 260, 'cause': 261, 'very': 262, 'favourite': 263, 'happy': 264, 'hair': 265, 'opinion': 266, 'cute': 267, 'hi': 268, 'around': 269, 'while': 270, 'cool': 271, 'talking': 272, 'year': 273, 'parents': 274, 'play': 275, 'sure': 276, 'actually': 277, 'show': 278, 'try': 279, 'explain': 280, 'those': 281, 'drink': 282, 'went': 283, 'y': 284, 'l': 285, 'ppl': 286, 'sleep': 287, 'b': 288, 'music': 289, 'phone': 290, 'color': 291, 'getting': 292, 'without': 293, 'asking': 294, 'lot': 295, 'though': 296, 'after': 297, 'didnt': 298, 'makes': 299, 'thanks': 300, 'describe': 301, 'relationship': 302, 'tabi': 303, 'having': 304, 'v': 305, 'called': 306, 'age': 307, 'wear': 308, 'worst': 309, 'happened': 310, 'ya': 311, 'our': 312, 'ill': 313, 'home': 314, 'read': 315, 'morni ...

# %%
len(tokenizer.word_index)
X = tokenizer.texts_to_sequences(X)
X = sequence.pad_sequences(X,maxlen=250)

# %%
y = df['ans1'].values.astype(int)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from tensorflow.keras.layers import Embedding
model = Sequential()
model.add(Embedding(20000,120))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='linear')) #regression
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 120)         2400000
# _________________________________________________________________
# dense (Dense)                (None, None, 8)           968
# _________________________________________________________________
# dense_1 (Dense)              (None, None, 1)           9
# =================================================================
# Total params: 2,400,977
# Trainable params: 2,400,977
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy',f1_m,precision_m, recall_m])

# %%
history = model.fit(X_train,y_train,batch_size=45,epochs=3,verbose=2,validation_data=(X_test,y_test))
# Out:
# Train on 9546 samples, validate on 3183 samples
# Epoch 1/3
# 9546/9546 - 30s - loss: 0.5886 - accuracy: 0.9153 - f1_m: 0.0000e+00 - precision_m: 0.0000e+00 - recall_m: 0.0000e+00 - val_loss: 0.2712 - val_accuracy: 0.9281 - val_f1_m: 0.0000e+00 - val_precision_m: 0.0000e+00 - val_recall_m: 0.0000e+00
# Epoch 2/3
# 9546/9546 - 22s - loss: 0.2981 - accuracy: 0.9153 - f1_m: 0.0513 - precision_m: 0.0939 - recall_m: 0.0388 - val_loss: 0.2677 - val_accuracy: 0.9281 - val_f1_m: 0.0164 - val_precision_m: 0.0282 - val_recall_m: 0.0117
# Epoch 3/3
# 9546/9546 - 26s - loss: 0.2951 - accuracy: 0.9153 - f1_m: 0.1701 - precision_m: 0.3082 - recall_m: 0.1326 - val_loss: 0.2666 - val_accuracy: 0.9280 - val_f1_m: 0.0786 - val_precision_m: 0.1385 - val_recall_m: 0.0573

# %%
loss, accuracy, f1_score, precision, recall = model.evaluate(X_test,y_test,batch_size=45,verbose=2)
# Out:
# 3183/3183 - 1s - loss: 0.2666 - accuracy: 0.9280 - f1_m: 0.0786 - precision_m: 0.1385 - recall_m: 0.0573

# %%
from sklearn.metrics import roc_curve

# %%
y_pred = model.predict(X_test)

# %%
results = []
for result in y_pred:
  results.append(result[-1][0])

# %%
results = np.array(results)

# %%
fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, results)

# %%
import matplotlib.pyplot as plt
plt.plot(fpr_keras, tpr_keras, marker='.', label='ROC Curve',color='orange')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
def get_roc_area_and_rates():
    from sklearn.metrics import confusion_matrix,roc_auc_score
    tn, fp, fn, tp = confusion_matrix(y_test,main).ravel()
    true_positive_rate = (tp)/(tp + fn)
    false_positive_rate = (fp)/(tn + fp)
    area = roc_auc_score(y_test,main)
    print("ROC area ",area)
    print("True positive rate ",true_positive_rate)
    print("False positive rate ",false_positive_rate)

get_roc_area_and_rates()
# Out:
# ROC area  0.5248297771063143
# True positive rate  0.056768558951965066
# False positive rate  0.0071090047393364926

# %%
results = []
for result in y_pred:
    results.append(max(result))

# %%
main = []
for result in results:
    if result > 0.5:
        main.append(1)
    else:
        main.append(0)
